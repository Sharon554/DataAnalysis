# %% [markdown]
# #MIDMARKS
# --------

# %% [markdown]
# T.Sharon 2211CS010554 GROUP-3
# -----------------------------

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_excel("MIDMARKS.xlsx")

# %%
df
# Out:
#      S.NO SECTION  DV M-II  PP BEEE  FL FIMS
# 0     1.0   ALPHA  12    0  17    9  19   15
# 1     2.0   ALPHA  19   12  16   16  18    3
# 2     3.0   ALPHA  18   14  18   18  18   16
# 3     4.0   ALPHA  15    9  19   17  19   15
# 4     5.0   ALPHA  18   17  19   19  20   18
# ..    ...     ...  ..  ...  ..  ...  ..  ...
# 713   NaN    ZETA  19    8   8   19  17   18
# 714   NaN    ZETA  12    1   7   10  20    8
# 715   NaN    ZETA  17    6  14   14  17   18
# 716   NaN    ZETA  12    1   6    7  15   12
# 717   NaN    ZETA  19   14  17   16  20   19
#
# [718 rows x 8 columns]

# %%
df.shape
# Out:
# (718, 8)

# %%
df.size
# Out:
# 5744

# %%
df.rename(columns={'M-II':'M2'},inplace=True)

# %%
df
# Out:
#      S.NO SECTION  DV  M2  PP BEEE  FL FIMS
# 0     1.0   ALPHA  12   0  17    9  19   15
# 1     2.0   ALPHA  19  12  16   16  18    3
# 2     3.0   ALPHA  18  14  18   18  18   16
# 3     4.0   ALPHA  15   9  19   17  19   15
# 4     5.0   ALPHA  18  17  19   19  20   18
# ..    ...     ...  ..  ..  ..  ...  ..  ...
# 713   NaN    ZETA  19   8   8   19  17   18
# 714   NaN    ZETA  12   1   7   10  20    8
# 715   NaN    ZETA  17   6  14   14  17   18
# 716   NaN    ZETA  12   1   6    7  15   12
# 717   NaN    ZETA  19  14  17   16  20   19
#
# [718 rows x 8 columns]

# %%
df=df.replace("A","AB")

# %%
df
# Out:
#      S.NO SECTION  DV  M2  PP BEEE  FL FIMS
# 0     1.0   ALPHA  12   0  17    9  19   15
# 1     2.0   ALPHA  19  12  16   16  18    3
# 2     3.0   ALPHA  18  14  18   18  18   16
# 3     4.0   ALPHA  15   9  19   17  19   15
# 4     5.0   ALPHA  18  17  19   19  20   18
# ..    ...     ...  ..  ..  ..  ...  ..  ...
# 713   NaN    ZETA  19   8   8   19  17   18
# 714   NaN    ZETA  12   1   7   10  20    8
# 715   NaN    ZETA  17   6  14   14  17   18
# 716   NaN    ZETA  12   1   6    7  15   12
# 717   NaN    ZETA  19  14  17   16  20   19
#
# [718 rows x 8 columns]

# %%
df=df.replace("AB",-1)
df=df.replace("MP",-2)
# Out:
# C:\Users\sharo\AppData\Local\Temp\ipykernel_18328\286352500.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df=df.replace("AB",-1)
# C:\Users\sharo\AppData\Local\Temp\ipykernel_18328\286352500.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df=df.replace("MP",-2)

# %%
df
# Out:
#      S.NO SECTION    DV    M2    PP  BEEE    FL  FIMS
# 0     1.0   ALPHA  12.0   0.0  17.0   9.0  19.0  15.0
# 1     2.0   ALPHA  19.0  12.0  16.0  16.0  18.0   3.0
# 2     3.0   ALPHA  18.0  14.0  18.0  18.0  18.0  16.0
# 3     4.0   ALPHA  15.0   9.0  19.0  17.0  19.0  15.0
# 4     5.0   ALPHA  18.0  17.0  19.0  19.0  20.0  18.0
# ..    ...     ...   ...   ...   ...   ...   ...   ...
# 713   NaN    ZETA  19.0   8.0   8.0  19.0  17.0  18.0
# 714   NaN    ZETA  12.0   1.0   7.0  10.0  20.0   8.0
# 715   NaN    ZETA  17.0   6.0  14.0  14.0  17.0  18.0
# 716   NaN    ZETA  12.0   1.0   6.0   7.0  15.0  12.0
# 717   NaN    ZETA  19.0  14.0  17.0  16.0  20.0  19.0
#
# [718 rows x 8 columns]

# %%
b = df.dropna()
b
# Out:
#       S.NO SECTION    DV    M2    PP  BEEE    FL  FIMS
# 0      1.0   ALPHA  12.0   0.0  17.0   9.0  19.0  15.0
# 1      2.0   ALPHA  19.0  12.0  16.0  16.0  18.0   3.0
# 2      3.0   ALPHA  18.0  14.0  18.0  18.0  18.0  16.0
# 3      4.0   ALPHA  15.0   9.0  19.0  17.0  19.0  15.0
# 4      5.0   ALPHA  18.0  17.0  19.0  19.0  20.0  18.0
# ..     ...     ...   ...   ...   ...   ...   ...   ...
# 596  597.0   SIGMA  20.0  20.0  20.0  20.0  20.0  20.0
# 597  598.0   SIGMA  20.0  20.0  20.0  19.0  19.0  18.0
# 598  599.0   SIGMA  20.0  20.0  17.0  17.0  19.0  18.0
# 599  600.0   SIGMA  14.0  12.0  11.0   9.0  18.0  17.0
# 600  601.0   SIGMA  20.0  19.0  20.0  18.0  18.0  19.0
#
# [599 rows x 8 columns]

# %%
df['S.NO'] = range(1, len(df) + 1)
df
# Out:
#      S.NO SECTION    DV    M2    PP  BEEE    FL  FIMS
# 0       1   ALPHA  12.0   0.0  17.0   9.0  19.0  15.0
# 1       2   ALPHA  19.0  12.0  16.0  16.0  18.0   3.0
# 2       3   ALPHA  18.0  14.0  18.0  18.0  18.0  16.0
# 3       4   ALPHA  15.0   9.0  19.0  17.0  19.0  15.0
# 4       5   ALPHA  18.0  17.0  19.0  19.0  20.0  18.0
# ..    ...     ...   ...   ...   ...   ...   ...   ...
# 713   714    ZETA  19.0   8.0   8.0  19.0  17.0  18.0
# 714   715    ZETA  12.0   1.0   7.0  10.0  20.0   8.0
# 715   716    ZETA  17.0   6.0  14.0  14.0  17.0  18.0
# 716   717    ZETA  12.0   1.0   6.0   7.0  15.0  12.0
# 717   718    ZETA  19.0  14.0  17.0  16.0  20.0  19.0
#
# [718 rows x 8 columns]

# %%
df['SECTION'] = df['SECTION'].fillna('SIGMA')
df['SECTION'] = df['SECTION'].replace('', 'SIGMA')
print("Updated DataFrame with missing sections replaced by 'SIGMA':")
df
# Out:
# Updated DataFrame with missing sections replaced by 'SIGMA':
#      S.NO SECTION    DV    M2    PP  BEEE    FL  FIMS
# 0       1   ALPHA  12.0   0.0  17.0   9.0  19.0  15.0
# 1       2   ALPHA  19.0  12.0  16.0  16.0  18.0   3.0
# 2       3   ALPHA  18.0  14.0  18.0  18.0  18.0  16.0
# 3       4   ALPHA  15.0   9.0  19.0  17.0  19.0  15.0
# 4       5   ALPHA  18.0  17.0  19.0  19.0  20.0  18.0
# ..    ...     ...   ...   ...   ...   ...   ...   ...
# 713   714    ZETA  19.0   8.0   8.0  19.0  17.0  18.0
# 714   715    ZETA  12.0   1.0   7.0  10.0  20.0   8.0
# 715   716    ZETA  17.0   6.0  14.0  14.0  17.0  18.0
# 716   717    ZETA  12.0   1.0   6.0   7.0  15.0  12.0
# 717   718    ZETA  19.0  14.0  17.0  16.0  20.0  19.0
#
# [718 rows x 8 columns]

# %%
df=df.fillna(0)
df
# Out:
#      S.NO SECTION    DV    M2    PP  BEEE    FL  FIMS
# 0       1   ALPHA  12.0   0.0  17.0   9.0  19.0  15.0
# 1       2   ALPHA  19.0  12.0  16.0  16.0  18.0   3.0
# 2       3   ALPHA  18.0  14.0  18.0  18.0  18.0  16.0
# 3       4   ALPHA  15.0   9.0  19.0  17.0  19.0  15.0
# 4       5   ALPHA  18.0  17.0  19.0  19.0  20.0  18.0
# ..    ...     ...   ...   ...   ...   ...   ...   ...
# 713   714    ZETA  19.0   8.0   8.0  19.0  17.0  18.0
# 714   715    ZETA  12.0   1.0   7.0  10.0  20.0   8.0
# 715   716    ZETA  17.0   6.0  14.0  14.0  17.0  18.0
# 716   717    ZETA  12.0   1.0   6.0   7.0  15.0  12.0
# 717   718    ZETA  19.0  14.0  17.0  16.0  20.0  19.0
#
# [718 rows x 8 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 718 entries, 0 to 717
# Data columns (total 8 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   S.NO     718 non-null    int64
#  1   SECTION  718 non-null    object
#  2   DV       718 non-null    float64
#  3   M2       718 non-null    float64
#  4   PP       718 non-null    float64
#  5   BEEE     718 non-null    float64
#  6   FL       718 non-null    float64
#  7   FIMS     718 non-null    float64
# dtypes: float64(6), int64(1), object(1)
# memory usage: 45.0+ KB

# %%
df['DV'] = pd.to_numeric(df['DV'], errors='coerce')
df['DV'] = df['DV'].fillna(0)
df['DV'] = df['DV'].astype(int)

# %%
df['M2'] = pd.to_numeric(df['M2'], errors='coerce')
df['M2'] = df['M2'].fillna(0)
df['M2'] = df['M2'].astype(int)

# %%
df['PP'] = pd.to_numeric(df['PP'], errors='coerce')
df['PP'] = df['PP'].fillna(0)
df['PP'] = df['PP'].astype(int)

# %%
df['BEEE'] = pd.to_numeric(df['BEEE'], errors='coerce')
df['BEEE'] = df['BEEE'].fillna(0)
df['BEEE'] = df['BEEE'].astype(int)

# %%
df['FL'] = pd.to_numeric(df['FL'], errors='coerce')
df['FL'] = df['FL'].fillna(0)
df['FL'] = df['FL'].astype(int)

# %%
df['FIMS'] = pd.to_numeric(df['FIMS'], errors='coerce')
df['FIMS'] = df['FIMS'].fillna(0)
df['FIMS'] = df['FIMS'].astype(int)

# %%
df
# Out:
#      S.NO SECTION  DV  M2  PP  BEEE  FL  FIMS
# 0       1   ALPHA  12   0  17     9  19    15
# 1       2   ALPHA  19  12  16    16  18     3
# 2       3   ALPHA  18  14  18    18  18    16
# 3       4   ALPHA  15   9  19    17  19    15
# 4       5   ALPHA  18  17  19    19  20    18
# ..    ...     ...  ..  ..  ..   ...  ..   ...
# 713   714    ZETA  19   8   8    19  17    18
# 714   715    ZETA  12   1   7    10  20     8
# 715   716    ZETA  17   6  14    14  17    18
# 716   717    ZETA  12   1   6     7  15    12
# 717   718    ZETA  19  14  17    16  20    19
#
# [718 rows x 8 columns]

# %%
df['Total']=df['DV']+df['M2']+df['PP']+df['BEEE']+df['FL']+df['FIMS']
df
# Out:
#      S.NO SECTION  DV  M2  PP  BEEE  FL  FIMS  Total
# 0       1   ALPHA  12   0  17     9  19    15     72
# 1       2   ALPHA  19  12  16    16  18     3     84
# 2       3   ALPHA  18  14  18    18  18    16    102
# 3       4   ALPHA  15   9  19    17  19    15     94
# 4       5   ALPHA  18  17  19    19  20    18    111
# ..    ...     ...  ..  ..  ..   ...  ..   ...    ...
# 713   714    ZETA  19   8   8    19  17    18     89
# 714   715    ZETA  12   1   7    10  20     8     58
# 715   716    ZETA  17   6  14    14  17    18     86
# 716   717    ZETA  12   1   6     7  15    12     53
# 717   718    ZETA  19  14  17    16  20    19    105
#
# [718 rows x 9 columns]

# %%
df['Percentage']=round((df['Total']/120)*100,2)
df
# Out:
#      S.NO SECTION  DV  M2  PP  BEEE  FL  FIMS  Total  Percentage
# 0       1   ALPHA  12   0  17     9  19    15     72       60.00
# 1       2   ALPHA  19  12  16    16  18     3     84       70.00
# 2       3   ALPHA  18  14  18    18  18    16    102       85.00
# 3       4   ALPHA  15   9  19    17  19    15     94       78.33
# 4       5   ALPHA  18  17  19    19  20    18    111       92.50
# ..    ...     ...  ..  ..  ..   ...  ..   ...    ...         ...
# 713   714    ZETA  19   8   8    19  17    18     89       74.17
# 714   715    ZETA  12   1   7    10  20     8     58       48.33
# 715   716    ZETA  17   6  14    14  17    18     86       71.67
# 716   717    ZETA  12   1   6     7  15    12     53       44.17
# 717   718    ZETA  19  14  17    16  20    19    105       87.50
#
# [718 rows x 10 columns]

# %%
df.loc[df["Total"]>110,["Grade"]]="A+"
df.loc[(df["Total"]>90) & (df["Total"]<=110),["Grade"]]="A"
df.loc[(df["Total"]>70) & (df["Total"]<=90),["Grade"]]="B+"
df.loc[(df["Total"]>50) & (df["Total"]<=70),["Grade"]]="B"
df.loc[(df["Total"]<=50),["Grade"]]="Fail"
df
# Out:
#      S.NO SECTION  DV  M2  PP  BEEE  FL  FIMS  Total  Percentage Grade
# 0       1   ALPHA  12   0  17     9  19    15     72       60.00    B+
# 1       2   ALPHA  19  12  16    16  18     3     84       70.00    B+
# 2       3   ALPHA  18  14  18    18  18    16    102       85.00     A
# 3       4   ALPHA  15   9  19    17  19    15     94       78.33     A
# 4       5   ALPHA  18  17  19    19  20    18    111       92.50    A+
# ..    ...     ...  ..  ..  ..   ...  ..   ...    ...         ...   ...
# 713   714    ZETA  19   8   8    19  17    18     89       74.17    B+
# 714   715    ZETA  12   1   7    10  20     8     58       48.33     B
# 715   716    ZETA  17   6  14    14  17    18     86       71.67    B+
# 716   717    ZETA  12   1   6     7  15    12     53       44.17     B
# 717   718    ZETA  19  14  17    16  20    19    105       87.50     A
#
# [718 rows x 11 columns]

# %%
failed_students_Total = df[df["Total"] < 50]
print("DataFrame of students who failed in subjects:")
print(failed_students_Total)
# Out:
# DataFrame of students who failed in subjects:
#      S.NO SECTION  DV  M2  PP  BEEE  FL  FIMS  Total  Percentage Grade
# 20     21   ALPHA   4   2   5     3  16     9     39       32.50  Fail
# 27     28   ALPHA   5   4   3    12  13     5     42       35.00  Fail
# 57     58   ALPHA   2   2   4    10  10     3     31       25.83  Fail
# 75     76   ALPHA   5   8   7    15  10     2     47       39.17  Fail
# 82     83   ALPHA   2   0   2    -1  -1    -1      1        0.83  Fail
# ..    ...     ...  ..  ..  ..   ...  ..   ...    ...         ...   ...
# 669   670    ZETA  16   6  -1    -1   8     9     37       30.83  Fail
# 673   674    ZETA   2  -1   0     0   2     1      4        3.33  Fail
# 679   680    ZETA  11   0   8     4   1    11     35       29.17  Fail
# 685   686    ZETA   5   1   4    15   1     6     32       26.67  Fail
# 689   690    ZETA   6   3   4     9  10    15     47       39.17  Fail
#
# [90 rows x 11 columns]

# %%
df.sort_values(["Total"], ascending=True)
# Out:
#      S.NO  SECTION  DV  M2  PP  BEEE  FL  FIMS  Total  Percentage Grade
# 414   415    GAMMA  -1  -1  -1    -1  -1    -1     -6       -5.00  Fail
# 244   245    DELTA  -1  -1  -1    -1  -1    -1     -6       -5.00  Fail
# 402   403    GAMMA  -1  -1  -1    -1  -1    -1     -6       -5.00  Fail
# 336   337  EPSILON  -1  -1  -1    -1  -1    -1     -6       -5.00  Fail
# 556   557    SIGMA  -1  -1  -1    -1  -1    -1     -6       -5.00  Fail
# ..    ...      ...  ..  ..  ..   ...  ..   ...    ...         ...   ...
# 618   619    SIGMA  20  20  20    20  20    19    119       99.17    A+
# 574   575    SIGMA  20  20  20    20  20    20    120      100.00    A+
# 507   508    OMEGA  20  20  20    20  20    20    120      100.00    A+
# 505   506    OMEGA  20  20  20    20  20    20    120      100.00    A+
# 596   597    SIGMA  20  20  20    20  20    20    120      100.00    A+
#
# [718 rows x 11 columns]

# %%
plt.figure(figsize=(5, 5))
sns.lineplot(x="DV", y="Total", data=df, marker="o")
plt.xlabel("DV")
plt.ylabel("Total")
plt.title("Marks in DV comparing with Percentage")
plt.show()

# %%
plt.figure(figsize=(5, 5))
sns.lineplot(x="PP", y="Total", data=df, marker="o")
plt.xlabel("PP")
plt.ylabel("Total")
plt.title("Marks in PP comparing with Percentage")
plt.show()

# %% [markdown]
# Students who scored 0 in PP has scored 90 and student who scored 20 has scored maximum marks
# --------------------------------------------------------------------------------------------

# %%
plt.figure(figsize=(5, 5))
sns.lineplot(x="FIMS", y="Total", data=df, marker="o")
plt.xlabel("FIMS")
plt.ylabel("Total")
plt.title("Marks in FIMS comparing with Percentage")
plt.show()

# %% [markdown]
# continuosly graph is increasing in FIMS and total score is also increasing
# --------------------------------------------------------------------------

# %%
plt.figure(figsize=(5, 5))
sns.lineplot(x="M2", y="Total", data=df, marker="o")
plt.xlabel("M2")
plt.ylabel("Total")
plt.title("Marks in M2 comparing with Percentage")
plt.show()

# %% [markdown]
# students those who got min marks they got min marks in total and who scored max marks got max marks in total
# ------------------------------------------------------------------------------------------------------------

# %%
plt.figure(figsize=(5, 5))
sns.lineplot(x="BEEE", y="Total", data=df, marker="o")
plt.xlabel("BEEE")
plt.ylabel("Total")
plt.title("Marks in BEEE comparing with Percentage")
plt.show()

# %% [markdown]
# continuosly graph is increasing in BEEE and total score is also increasing
# --------------------------------------------------------------------------

# %%
plt.figure(figsize=(5, 5))

sns.lineplot(x="FL", y="Total", data=df, marker="o")
plt.xlabel("FL")
plt.ylabel("Total")
plt.title("Marks in FL comparing with Percentage")
plt.show()

# %%
plt.figure(figsize=(5, 5))

sns.scatterplot(x="M2", y="Total", data=df, marker="o")
plt.xlabel("M2")
plt.ylabel("Total")
plt.title("Marks in M2 comparing with Percentage")
plt.show()

# %%
plt.figure(figsize=(5, 5))

sns.barplot(x="M2", y="Total", data=df)
plt.xlabel("M2")
plt.ylabel("Total")
plt.title("Marks in M2 comparing with Percentage")
plt.show()

# %%
plt.figure(figsize=(5, 5))

sns.histplot(x="M2", y="Total", data=df)
plt.xlabel("M2")
plt.ylabel("Total")
plt.title("Marks in M2 comparing with Percentage")
plt.show()

# %%
plt.figure(figsize=(5, 5))
sns.boxplot(x="M2", y="Total", data=df)
plt.xlabel("M2")
plt.ylabel("Total")
plt.title("Marks in M2 comparing with Percentage")
plt.show()

# %%
df.rename(columns={'M-II':'M2'},inplace=True)
df['S.NO'] = range(1, len(df) + 1)
df
df['SECTION'] = df['SECTION'].fillna('SIGMA')
df['SECTION'] = df['SECTION'].replace('', 'SIGMA')
df
# Out:
#      S.NO SECTION  DV  M2  PP  BEEE  FL  FIMS  Total  Percentage Grade
# 0       1   ALPHA  12   0  17     9  19    15     72       60.00    B+
# 1       2   ALPHA  19  12  16    16  18     3     84       70.00    B+
# 2       3   ALPHA  18  14  18    18  18    16    102       85.00     A
# 3       4   ALPHA  15   9  19    17  19    15     94       78.33     A
# 4       5   ALPHA  18  17  19    19  20    18    111       92.50    A+
# ..    ...     ...  ..  ..  ..   ...  ..   ...    ...         ...   ...
# 713   714    ZETA  19   8   8    19  17    18     89       74.17    B+
# 714   715    ZETA  12   1   7    10  20     8     58       48.33     B
# 715   716    ZETA  17   6  14    14  17    18     86       71.67    B+
# 716   717    ZETA  12   1   6     7  15    12     53       44.17     B
# 717   718    ZETA  19  14  17    16  20    19    105       87.50     A
#
# [718 rows x 11 columns]

# %%
df['S.NO'] = range(1, len(df) + 1)
df
# Out:
#      S.NO SECTION  DV  M2  PP  BEEE  FL  FIMS  Total  Percentage Grade
# 0       1   ALPHA  12   0  17     9  19    15     72       60.00    B+
# 1       2   ALPHA  19  12  16    16  18     3     84       70.00    B+
# 2       3   ALPHA  18  14  18    18  18    16    102       85.00     A
# 3       4   ALPHA  15   9  19    17  19    15     94       78.33     A
# 4       5   ALPHA  18  17  19    19  20    18    111       92.50    A+
# ..    ...     ...  ..  ..  ..   ...  ..   ...    ...         ...   ...
# 713   714    ZETA  19   8   8    19  17    18     89       74.17    B+
# 714   715    ZETA  12   1   7    10  20     8     58       48.33     B
# 715   716    ZETA  17   6  14    14  17    18     86       71.67    B+
# 716   717    ZETA  12   1   6     7  15    12     53       44.17     B
# 717   718    ZETA  19  14  17    16  20    19    105       87.50     A
#
# [718 rows x 11 columns]

# %%
df['FL'] = df['FL'].fillna(0)
df=df.dropna()

# %%
df['FL'] = df['FL'].fillna(0)
df=df.dropna()
df['S.NO'] = range(1, len(df) + 1)
df
# Out:
#      S.NO SECTION  DV  M2  PP  BEEE  FL  FIMS  Total  Percentage Grade
# 0       1   ALPHA  12   0  17     9  19    15     72       60.00    B+
# 1       2   ALPHA  19  12  16    16  18     3     84       70.00    B+
# 2       3   ALPHA  18  14  18    18  18    16    102       85.00     A
# 3       4   ALPHA  15   9  19    17  19    15     94       78.33     A
# 4       5   ALPHA  18  17  19    19  20    18    111       92.50    A+
# ..    ...     ...  ..  ..  ..   ...  ..   ...    ...         ...   ...
# 713   714    ZETA  19   8   8    19  17    18     89       74.17    B+
# 714   715    ZETA  12   1   7    10  20     8     58       48.33     B
# 715   716    ZETA  17   6  14    14  17    18     86       71.67    B+
# 716   717    ZETA  12   1   6     7  15    12     53       44.17     B
# 717   718    ZETA  19  14  17    16  20    19    105       87.50     A
#
# [718 rows x 11 columns]

# %%
df.DV.mean
# Out:
# <bound method Series.mean of 0      12
# 1      19
# 2      18
# 3      15
# 4      18
#        ..
# 713    19
# 714    12
# 715    17
# 716    12
# 717    19
# Name: DV, Length: 718, dtype: int32>

# %%
df.M2.mean
# Out:
# <bound method Series.mean of 0       0
# 1      12
# 2      14
# 3       9
# 4      17
#        ..
# 713     8
# 714     1
# 715     6
# 716     1
# 717    14
# Name: M2, Length: 718, dtype: int32>

# %%
print(df.describe())
print(df[MIDMARKS.xlsx].mean())
# Out:
#              S.NO          DV          M2          PP        BEEE          FL  \
# count  718.000000  718.000000  718.000000  718.000000  718.000000  718.000000
# mean   359.500000   14.729805    9.905292   12.711699   13.224234   15.483287
# std    207.413034    4.684403    6.637197    5.898647    5.879651    4.607813
# min      1.000000   -2.000000   -1.000000   -2.000000   -1.000000   -1.000000
# 25%    180.250000   12.000000    4.000000    9.000000    9.000000   13.000000
# 50%    359.500000   16.000000   10.000000   14.000000   15.000000   16.000000
# 75%    538.750000   18.000000   16.000000   18.000000   18.000000   20.000000
# max    718.000000   20.000000   20.000000   20.000000   20.000000   20.000000
#
#              FIMS       Total  Percentage
# count  718.000000  718.000000  718.000000
# mean    13.977716   80.032033   66.693259
# std      4.853739   25.983158   21.652705
# min     -1.000000   -6.000000   -5.000000
# 25%     12.000000   64.000000   53.330000
# ...

# %%
import pandas as pd

df = pd.read_excel("MIDMARKS.xlsx")
print(df.describe())
print(df["MIDMARKS.xlsx"].median())
# Out:
#              S.NO
# count  601.000000
# mean   301.000000
# std    173.638033
# min      1.000000
# 25%    151.000000
# 50%    301.000000
# 75%    451.000000
# max    601.000000
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'MIDMARKS.xlsx'
#
# ...

# %%
import pandas as pd
from scipy.stats import ttest_ind
df = pd.DataFrame({'method': ['A', 'A', 'A', 'A', 'A', 'A', 'A', 'A', 'A', 'A',
                              'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B'],
                   'score': [71, 72, 72, 75, 78, 81, 82, 83, 89, 91, 80, 81, 81,
                             84, 88, 88, 89, 90, 90, 91]})
df.head()
# Out:
#   method  score
# 0      A     71
# 1      A     72
# 2      A     72
# 3      A     75
# 4      A     78

# %%
df[df['SECTION']=='BETA']['DV']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'SECTION'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 df[df['SECTION']=='BETA']['DV']
#
# ...

# %%
import pandas as pd

mean_dv = df[df['SECTION'].str.strip() == 'ALPHA']['DV'].mean()
print(mean_dv)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'SECTION'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[52], line 3
#       1 import pandas as pd
# ...

# %%
df.DV.mean()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_18328\739317843.py in ?()
# ----> 1 df.DV.mean()
#
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'DV'

# %%
import scipy.stats as stats
t_statistic, p_value = stats.ttest_1samp(df[df['SECTION'].str.strip() == 'ALPHA']['DV'], 14.41)
print(t_statistic, p_value)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'SECTION'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[54], line 2
#       1 import scipy.stats as stats
# ...

# %%
df=df.fillna(0)
df=df.replace("AB",-1)
df=df.replace("A",-1)
df=df.replace("MP",-2)
df
# Out:
#    method  score
# 0      -1     71
# 1      -1     72
# 2      -1     72
# 3      -1     75
# 4      -1     78
# 5      -1     81
# 6      -1     82
# 7      -1     83
# 8      -1     89
# 9      -1     91
# 10      B     80
# 11      B     81
# 12      B     81
# 13      B     84
# 14      B     88
# 15      B     88
# 16      B     89
# 17      B     90
# 18      B     90
# 19      B     91

# %%
df['DV']=df['DV'].astype(int)
df['M2']=df['M2'].astype(int)
df['PP']=df['PP'].astype(int)
df['BEEE']=df['BEEE'].astype(int)
df['FL']=df['FL'].astype(int)
df['FIMS']=df['FIMS'].astype(int)
df.info()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'DV'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[56], line 1
# ----> 1 df['DV']=df['DV'].astype(int)
#       2 df['M2']=df['M2'].astype(int)
# ...

# %%
from scipy.stats import chi2_contingency


data = [[207, 282, 241], [234, 242, 232]]
stat, p, dof, expected = chi2_contingency(data)


alpha = 0.05
print("p value is " + str(p))
if p <= alpha:
    print('Dependent (reject H0)')
else:
    print('Independent (H0 holds true)')
# Out:
# p value is 0.1031971404730939
# Independent (H0 holds true)
